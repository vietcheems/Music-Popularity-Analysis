# %%
import requests
import json

# %%
key = "AIzaSyDsayLz55WJ4o5Oe7zkA8ul1srKJ-7y1os"

# %%
r = requests.get('https://www.googleapis.com/youtube/v3/search?part=id%2Csnippet&maxResults=20&regionCode=VN&order=viewCount&type=video&videoCategoryId=10&key=AIzaSyDsayLz55WJ4o5Oe7zkA8ul1srKJ-7y1os')

# %%
r = requests.get('https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults=25&q=surfing&key=AIzaSyDsayLz55WJ4o5Oe7zkA8ul1srKJ-7y1os')

# %%
r.status_code
# Out:
# 200

# %%
type(r)
# Out:
# requests.models.Response

# %%
d = json.loads(r.content)

# %%
d
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'oOCCNgQDBwgkfsg2C-OJWQjMe6U',
#  'nextPageToken': 'CBQQAA',
#  'regionCode': 'VN',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'RrUcvT-sBn9pXNyFtf1x0fumavM',
#    'id': {'kind': 'youtube#video', 'videoId': 'j8U06veqxdU'},
#    'snippet': {'publishedAt': '2019-07-12T12:57:48Z',
#     'channelId': 'UCaqULXPDXdu561DMeWFq5Fw',
#     'title': 'SÓNG GIÓ | K-ICM x JACK | OFFICIAL MUSIC VIDEO',
#     'description': 'SÓNG GIÓ | K-ICM x JACK | OFFICIAL MUSIC VIDEO Sóng Gió là câu chuyện tiếp theo của Bạc Phận, mọi người cùng chờ đón xem điều gì sẽ xảy ra vào cuối ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j8U06veqxdU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/j8U06veqxdU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
d.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])

# %%
len(d['items'])
# Out:
# 20

# %%
for item in d['items']:
	print(item['snippet']['title'])
# Out:
# SÓNG GIÓ | K-ICM x JACK | OFFICIAL MUSIC VIDEO
# BẠC PHẬN | K-ICM ft. JACK | OFFICIAL MV
# EM GÌ ƠI | K-ICM x JACK | OFFICIAL MUSIC VIDEO
# NƠI NÀY CÓ ANH | OFFICIAL MUSIC VIDEO | SƠN TÙNG M-TP
# LẠC TRÔI | OFFICIAL MUSIC VIDEO | SƠN TÙNG M-TP
# SƠN TÙNG M-TP | HÃY TRAO CHO ANH ft. Snoop Dogg | Official MV
# Jack | Hoa Hải Đường | Official Music Video
# BÍCH PHƯƠNG x MIRINDA - Chuyện Cũ Bỏ Qua (Official M/V)
# THẰNG ĐIÊN | JUSTATEE x PHƯƠNG LY | OFFICIAL MV
# JACK - Là 1 Thằng Con Trai Official MV | J97
# CUỘC SỐNG EM ỔN KHÔNG | ANH TÚ | OFFICIAL MUSIC VIDEO
# JustaTee - Đã Lỡ Yêu Em Nhiều (Official MV)
# SƠN TÙNG M-TP | CÓ CHẮC YÊU LÀ ĐÂY | OFFICIAL MUSIC VIDEO
# SƠN TÙNG M-TP | MUỘN RỒI MÀ SAO CÒN | OFFICIAL MUSIC VIDEO
# THÍCH THÌ ĐẾN | LÊ BẢO BÌNH | OFFICIAL MUSIC VIDEO
# Jack | Đom Đóm | Official Music Video
# MIN - ĐỪNG YÊU NỮA, EM MỆT RỒI | OFFICIAL MUSIC VIDEO (민)
# Âm Thầm Bên Em | OFFICIAL MUSIC VIDEO | Sơn Tùng M-TP
# BƯỚC QUA ĐỜI NHAU - LÊ BẢO BÌNH [ OFFICIAL MV 4K ]
# ...

# %%
import pandas as pd
import os
import json

folder = "response"
for file_name in os.listdir(folder):
	file_path = os.path.join(folder, file_name)
	with open(file_path, 'r') as f:
		song = json.loads(f.read())

# %%
song.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])

# %%
song['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'C151uOVtD4blyg_BvE904chg2jU',
#   'id': {'kind': 'youtube#video', 'videoId': '2f1Ny74_ou0'},
#   'snippet': {'publishedAt': '2012-12-05T13:00:30Z',
#    'channelId': 'UCbulh9WdLtEXiooRcYK7SWw',
#    'title': 'Metallica - Master of Puppets (Live) [Quebec Magnetic]',
#    'description': 'From the DVD/Blu-Ray release Quebec Magnetic Buy it now in the Met Store at Metallica.com - http://bit.ly/MetStore Master of Puppets (Live) Recorded live on ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Metallica',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2012-12-05T13:00:30Z'}},
# ...

# %%
song['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'C151uOVtD4blyg_BvE904chg2jU',
#  'id': {'kind': 'youtube#video', 'videoId': '2f1Ny74_ou0'},
#  'snippet': {'publishedAt': '2012-12-05T13:00:30Z',
#   'channelId': 'UCbulh9WdLtEXiooRcYK7SWw',
#   'title': 'Metallica - Master of Puppets (Live) [Quebec Magnetic]',
#   'description': 'From the DVD/Blu-Ray release Quebec Magnetic Buy it now in the Met Store at Metallica.com - http://bit.ly/MetStore Master of Puppets (Live) Recorded live on ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Metallica',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2012-12-05T13:00:30Z'}}

# %%
song['items'][0].keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %%
song['items'][0]['snippet']
# Out:
# {'publishedAt': '2012-12-05T13:00:30Z',
#  'channelId': 'UCbulh9WdLtEXiooRcYK7SWw',
#  'title': 'Metallica - Master of Puppets (Live) [Quebec Magnetic]',
#  'description': 'From the DVD/Blu-Ray release Quebec Magnetic Buy it now in the Met Store at Metallica.com - http://bit.ly/MetStore Master of Puppets (Live) Recorded live on ...',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/2f1Ny74_ou0/hqdefault.jpg',
#    'width': 480,
#    'height': 360}},
#  'channelTitle': 'Metallica',
#  'liveBroadcastContent': 'none',
#  'publishTime': '2012-12-05T13:00:30Z'}

# %%
song['items'][0]['snippet'].keys()
# Out:
# dict_keys(['publishedAt', 'channelId', 'title', 'description', 'thumbnails', 'channelTitle', 'liveBroadcastContent', 'publishTime'])

# %%
a = song['items'][0]['snippet']

# %%
[a['publishedAt'], a['channelId']]
# Out:
# ['2018-05-18T04:04:58Z', 'UCx8v-goujcpBVF7QKALgp3g']

# %%
dict_variable = {key:value for (key,value) in a.items() if key in ['publishedAt', 'channelId', 'title', 'channelTitle']}

# %%
dict_variable
# Out:
# {'publishedAt': '2018-05-18T04:04:58Z',
#  'channelId': 'UCx8v-goujcpBVF7QKALgp3g',
#  'title': 'Dan + Shay - Speechless (Wedding Video)',
#  'channelTitle': 'Dan And Shay'}

# %%
output = pd.DataFrame()

# %%
output.append(dict_variable, ignore_index=True)
# Out:
#                   channelId  channelTitle           publishedAt  \
# 0  UCx8v-goujcpBVF7QKALgp3g  Dan And Shay  2018-05-18T04:04:58Z
#
#                                      title
# 0  Dan + Shay - Speechless (Wedding Video)

# %%
import requests
import bs4

# %%
r = requests.get("https://www.youtube.com/watch?v=kJQP7kiw5Fk")

# %%
r.status_code
# Out:
# 200

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/Spotify/spotify-playlist.csv", sep="\t")

# %%
df[df['track'].str.contains("with")]
# Out:
#       Unnamed: 0                                        track  \
# 73            73              It Ain't Me (with Selena Gomez)
# 89            89         Where Are Ü Now (with Justin Bieber)
# 97            97                     Stay (with Alessia Cara)
# 111          111                     One Kiss (with Dua Lipa)
# 150          150            El Perdón (with Enrique Iglesias)
# ...          ...                                          ...
# 4407        4407               Fair Trade (with Travis Scott)
# 4428        4428        Way 2 Sexy (with Future & Young Thug)
# 4429        4429  Knife Talk (with 21 Savage ft. Project Pat)
# 4430        4430             Girls Want Girls (with Lil Baby)
# 4459        4459      m y . l i f e (with 21 Savage & Morray)
#
#                     track_id         artist               artist_id  \
# 73    3eR23VReFzcdmS7TYCrhCe           Kygo  23fqKkggKUBHNkbKtXEls4
# 89    66hayvUbTotekKU3H4ta1f         Jack Ü  1HxJeLhIuegM3KgvPn8sTa
# ...

# %%
import os

# %%
len(os.listdir("/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/youtube/2_round/response"))
# Out:
# 313

# %%
import pandas as pd

# %%
yt_view = pd.read_csv("/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/youtube/2_round/view.tsv", sep="\t", names=['video_id', 'view'])
sp_songs_2 = pd.read_csv('/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/Spotify/spotify-playlist.csv', sep='\t')
yt_songs_2 = pd.read_csv("/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/youtube/2_round/youtube.csv")
yt_2 = yt_view.join(yt_songs_2.set_index("video_id"), on='video_id')
full_2 = yt_2.join(sp_songs_2, on="spotify_index")
full_sub_2 = full_2[["view", "track", "title"]].applymap(lambda x: x.replace(",", ""))


full_view = pd.read_csv('/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/youtube/view.tsv', sep='\t', names=['video_id', 'view'])
yt_songs = pd.read_csv("/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/youtube/youtube.csv")
yt = full_view.join(yt_songs.set_index("video_id"), on="video_id")
full = yt.join(sp_songs_2, on="spotify_index")
full_sub = full[["view", "track", "title"]].applymap(lambda x: x.replace(",", ""))

# %%
print(len(yt), len(yt.drop_duplicates()))
print(len(yt_2), len(yt_2.drop_duplicates()))
# Out:
# 4537 4533
# 314 314

# %%
full["spotify_index"].isin(list(yt_2["spotify_index"])).sum()
# Out:
# 316

# %%
final_yt = yt.loc[full["spotify_index"].isin(list(yt_2["spotify_index"])).apply(lambda x: not x)].append(yt_2)

# %%
len(final_yt), len(final_yt.drop_duplicates())
# Out:
# (4535, 4531)

# %%
final_drop_dup = final_yt.drop_duplicates().copy()

# %%
final_drop_dup['view'] = final_drop_dup['view'].apply(lambda x: x.replace(",", ""))

# %%
threshold = 1000000

# %%
len(final_drop_dup[pd.to_numeric(final_drop_dup["view"]) < threshold])
# Out:
# 129

# %%
len(full[pd.to_numeric(full["view"].apply(lambda x: x.replace(",", ""))) < threshold])
# Out:
# 224

# %%
final_drop_dup.head()
# Out:
#       video_id       view                 channelId       channelTitle  \
# 0  7UoP9ABJXGE  114782006  UCx8v-goujcpBVF7QKALgp3g       Dan And Shay
# 1  iBioIsLoXoE   17589349  UCUJTvb20oc_15y3DRNvZlEA           Swae Lee
# 2  cii6ruuycQA  185602030  UCxE5jEls-T0QtlTHT8lI1lw  OliviaRodrigoVEVO
# 3  5hEh9LiSzow  253256809  UCa10nxShhzNrCE1o2ZOPztg        Trap Nation
# 4  b4Bj7Zb-YD4  418549362  UCaHNFIob5Ixv74f5on3lvIw   CalvinHarrisVEVO
#
#             publishedAt  spotify_index  \
# 0  2018-05-18T04:04:58Z           2360
# 1  2019-08-16T04:30:03Z           3896
# 2  2021-04-01T16:00:27Z           4367
# 3  2014-12-18T12:51:02Z           2426
# 4  2016-10-28T07:00:01Z            323
#
#                                                title
# 0            Dan + Shay - Speechless (Wedding Video)
# 1  Swae Lee - Won&#39;t Be Late ft. Drake (Lyric ...
# 2          Olivia Rodrigo - deja vu (Official Video)
# 3  Jetta - I&#39;d Love to Change the World (Mats...
# ...

# %%
final_drop_dup.to_csv("/home/viet/OneDrive/Studying Materials/Introduction to Data Science/EDA Project/Music-Popularity-Analysis/Scrape/youtube/youtube_rescrape.csv", index=False)

# %%
# full_copy = full.copy()
# count = 0
# for index, row in full.iterrows():
# 	if row["spotify_index"] in list(full_2["spotify_index"]):
# 		count += 1
# 		print(full.iloc[index])
# 		# print(row["spotify_index"])
# 		# print((full_2["spotify_index"] == row["spotify_index"]))
# 		full.loc[full["spotify_index"] == row["spotify_index"]] = full_2.loc[full_2["spotify_index"] == row["spotify_index"]]
# 		print("------------------------")
# 		print(full.iloc[index])
# 		print("\n\n\n")
# print(count)
# Out:
# video_id                                                  DnGdoEa1tPg
# view                                                      287,285,400
# channelId                                    UCvtZDkeFxMkRTNqfqXtxxkw
# channelTitle                                        systemofadownVEVO
# publishedAt                                      2009-10-03T07:35:20Z
# spotify_index                                                    1705
# title               System Of A Down - Lonely Day (Official HD Video)
# Unnamed: 0                                                       1705
# track                                                      Lonely Day
# track_id                                       1VNWaY3uNfoeWqb5U8x2QX
# artist                                               System Of A Down
# artist_id                                      5eAWCfyUhZtHHtBdNk56l1
# album                                                       Hypnotize
# ...
